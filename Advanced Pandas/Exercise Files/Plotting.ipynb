# %%
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %%
import numpy as np
import pandas as pd

# %%
daterange = pd.period_range('1/1/1950', freq='1d', periods=50)
df = pd.DataFrame(data=daterange, columns=['day'])
df['value1'] = np.random.randint(45, 65, size=(len(df)))
df['value2'] = np.random.randint(25, 35, size=(len(df)))
df.head(3)
# Out:
#           day  value1  value2
# 0  1950-01-01      53      30
# 1  1950-01-02      51      27
# 2  1950-01-03      56      29

# %%
ax = df.plot()

# %%
df.plot.area(stacked=True)
# Out:
# <AxesSubplot:>

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.hist();

# %%
iris[['sepal_width', 'sepal_length']].plot.hist(alpha=0.5);

# %%
colors = {"versicolor":"red","setosa":"green","virginica":"blue"}
iris['colors'] = iris['species'].map(colors)
iris.plot.scatter(x='sepal_width', y='sepal_length', color=iris['colors']);

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(iris, figsize=(15, 9),);
